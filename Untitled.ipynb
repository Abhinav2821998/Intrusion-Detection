# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# reading the dataSet
df = pd.read_csv("CIDDS-001-external-week3.csv")
# Out:
# C:\Users\ABHINAV\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#            Date first seen  Duration  Proto Src IP Addr  Src Pt Dst IP Addr  \
# 0  2017-04-05 00:00:09.191     0.000  TCP      26913_25   43618  EXT_SERVER
# 1  2017-04-05 00:00:09.191     0.000  TCP    EXT_SERVER      23    26913_25
# 2  2017-04-05 00:02:56.395     0.000  TCP     26914_116    1817  EXT_SERVER
# 3  2017-04-05 00:02:56.395     0.000  TCP    EXT_SERVER      23   26914_116
# 4  2017-04-05 00:03:23.251     0.001  TCP     26915_202   57272  EXT_SERVER
#
#     Dst Pt  Packets     Bytes  Flows   Flags  Tos       class attackType  \
# 0     23.0        1        46      1  ....S.    0  suspicious        ---
# 1  43618.0        1        40      1  .A.R..    0  suspicious        ---
# 2     23.0        1        46      1  ....S.    0  suspicious        ---
# 3   1817.0        1        40      1  .A.R..    0  suspicious        ---
# 4   1433.0        1        46      1  ....S.    0  suspicious        ---
#
#   attackID attackDescription
# 0      ---               ---
# 1      ---               ---
# 2      ---               ---
# 3      ---               ---
# 4      ---               ---

# %%
df.drop(['Flows','Tos','attackID','attackType','attackDescription','Src Pt','Dst Pt'],axis=1,inplace=True)

# %%
#Dataset after droppring columns
df
# Out:
#                 Date first seen   Duration  Proto    Src IP Addr  \
# 0       2017-04-05 00:00:09.191      0.000  TCP         26913_25
# 1       2017-04-05 00:00:09.191      0.000  TCP       EXT_SERVER
# 2       2017-04-05 00:02:56.395      0.000  TCP        26914_116
# 3       2017-04-05 00:02:56.395      0.000  TCP       EXT_SERVER
# 4       2017-04-05 00:03:23.251      0.001  TCP        26915_202
# ...                         ...        ...    ...            ...
# 153021  2017-04-11 08:38:08.408  67601.294  TCP    OPENSTACK_NET
# 153022  2017-04-11 08:38:08.408  67601.294  TCP       EXT_SERVER
# 153023  2017-04-11 08:38:08.408  67601.294  TCP    OPENSTACK_NET
# 153024  2017-04-11 08:38:08.599  67601.103  TCP       EXT_SERVER
# 153025  2017-04-11 08:38:08.599  67601.103  TCP    OPENSTACK_NET
#
#           Dst IP Addr  Packets     Bytes   Flags       class
# 0          EXT_SERVER        1        46  ....S.  suspicious
# 1            26913_25        1        40  .A.R..  suspicious
# 2          EXT_SERVER        1        46  ....S.  suspicious
# 3           26914_116        1        40  .A.R..  suspicious
# 4          EXT_SERVER        1        46  ....S.  suspicious
# ...               ...      ...       ...     ...         ...
# 153021     EXT_SERVER   160681    12.2 M  .APRS.      normal
# 153022  OPENSTACK_NET   172810   465.7 M  .AP.S.      normal
# 153023     EXT_SERVER   170412    28.5 M  .APRS.      normal
# 153024  OPENSTACK_NET   148533   394.9 M  .AP.S.      normal
# 153025     EXT_SERVER   147538    29.5 M  .APRS.      normal
#
# [153026 rows x 9 columns]

# %%
#dependent variable
y=df.iloc[:,-1].values
y
# Out:
# array(['suspicious', 'suspicious', 'suspicious', ..., 'normal', 'normal',
#        'normal'], dtype=object)

# %%
#putting  the "Date first seen" as the X-axis on the dataset

df['Date'] = pd.to_datetime(df['Date first seen'])
df = df.set_index('Date')
df.drop(['Date first seen'], axis=1, inplace=True)
df.head()
# Out:
#                          Duration  Proto Src IP Addr Dst IP Addr  Packets  \
# Date
# 2017-04-05 00:00:09.191     0.000  TCP      26913_25  EXT_SERVER        1
# 2017-04-05 00:00:09.191     0.000  TCP    EXT_SERVER    26913_25        1
# 2017-04-05 00:02:56.395     0.000  TCP     26914_116  EXT_SERVER        1
# 2017-04-05 00:02:56.395     0.000  TCP    EXT_SERVER   26914_116        1
# 2017-04-05 00:03:23.251     0.001  TCP     26915_202  EXT_SERVER        1
#
#                             Bytes   Flags       class
# Date
# 2017-04-05 00:00:09.191        46  ....S.  suspicious
# 2017-04-05 00:00:09.191        40  .A.R..  suspicious
# 2017-04-05 00:02:56.395        46  ....S.  suspicious
# 2017-04-05 00:02:56.395        40  .A.R..  suspicious
# 2017-04-05 00:03:23.251        46  ....S.  suspicious

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11, 9)})
cols_plot=['Packets','Duration','Bytes']
df[cols_plot].plot(linewidth=0.5, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019AF95B1F48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AF9CD9248>],
#       dtype=object)

# %%
#acessing number of rows
n=df.shape[0]
print("number of rows : "+str(n))
resultat=df['class'].value_counts()
print("\nvalue repartition for class : \n"+str(resultat)+"\n")
resultat=resultat
resultat.plot(kind='bar')
# Out:
# number of rows : 153026
#
# value repartition for class :
# suspicious    97852
# unknown       33837
# attacker       9255
# normal         6180
# victim         5902
# Name: class, dtype: int64

# %%
df.loc[:,'Attacker']=0
df.loc[:,'Normal']=0
df.loc[:,'Unknown']=0
df.loc[:,'Suspicious']=0
df.loc[:,'Victim']=0
df
# Out:
#                           Duration  Proto    Src IP Addr    Dst IP Addr  \
# Date
# 2017-04-05 00:00:09.191      0.000  TCP         26913_25     EXT_SERVER
# 2017-04-05 00:00:09.191      0.000  TCP       EXT_SERVER       26913_25
# 2017-04-05 00:02:56.395      0.000  TCP        26914_116     EXT_SERVER
# 2017-04-05 00:02:56.395      0.000  TCP       EXT_SERVER      26914_116
# 2017-04-05 00:03:23.251      0.001  TCP        26915_202     EXT_SERVER
# ...                            ...    ...            ...            ...
# 2017-04-11 08:38:08.408  67601.294  TCP    OPENSTACK_NET     EXT_SERVER
# 2017-04-11 08:38:08.408  67601.294  TCP       EXT_SERVER  OPENSTACK_NET
# 2017-04-11 08:38:08.408  67601.294  TCP    OPENSTACK_NET     EXT_SERVER
# 2017-04-11 08:38:08.599  67601.103  TCP       EXT_SERVER  OPENSTACK_NET
# 2017-04-11 08:38:08.599  67601.103  TCP    OPENSTACK_NET     EXT_SERVER
#
#                          Packets     Bytes   Flags       class  Attacker  \
# Date
# 2017-04-05 00:00:09.191        1        46  ....S.  suspicious         0
# 2017-04-05 00:00:09.191        1        40  .A.R..  suspicious         0
# 2017-04-05 00:02:56.395        1        46  ....S.  suspicious         0
# 2017-04-05 00:02:56.395        1        40  .A.R..  suspicious         0
# 2017-04-05 00:03:23.251        1        46  ....S.  suspicious         0
# ...                          ...       ...     ...         ...       ...
# 2017-04-11 08:38:08.408   160681    12.2 M  .APRS.      normal         0
# 2017-04-11 08:38:08.408   172810   465.7 M  .AP.S.      normal         0
# 2017-04-11 08:38:08.408   170412    28.5 M  .APRS.      normal         0
# 2017-04-11 08:38:08.599   148533   394.9 M  .AP.S.      normal         0
# 2017-04-11 08:38:08.599   147538    29.5 M  .APRS.      normal         0
#
#                          Normal  Unknown  Suspicious  Victim
# Date
# 2017-04-05 00:00:09.191       0        0           0       0
# 2017-04-05 00:00:09.191       0        0           0       0
# 2017-04-05 00:02:56.395       0        0           0       0
# 2017-04-05 00:02:56.395       0        0           0       0
# 2017-04-05 00:03:23.251       0        0           0       0
# ...                         ...      ...         ...     ...
# 2017-04-11 08:38:08.408       0        0           0       0
# 2017-04-11 08:38:08.408       0        0           0       0
# 2017-04-11 08:38:08.408       0        0           0       0
# 2017-04-11 08:38:08.599       0        0           0       0
# 2017-04-11 08:38:08.599       0        0           0       0
#
# [153026 rows x 13 columns]

# %%
df= pd.get_dummies(df, columns=['Proto'])
df= pd.get_dummies(df, columns=['Flags'])
df
# Out:
#                           Duration    Src IP Addr    Dst IP Addr  Packets  \
# Date
# 2017-04-05 00:00:09.191      0.000       26913_25     EXT_SERVER        1
# 2017-04-05 00:00:09.191      0.000     EXT_SERVER       26913_25        1
# 2017-04-05 00:02:56.395      0.000      26914_116     EXT_SERVER        1
# 2017-04-05 00:02:56.395      0.000     EXT_SERVER      26914_116        1
# 2017-04-05 00:03:23.251      0.001      26915_202     EXT_SERVER        1
# ...                            ...            ...            ...      ...
# 2017-04-11 08:38:08.408  67601.294  OPENSTACK_NET     EXT_SERVER   160681
# 2017-04-11 08:38:08.408  67601.294     EXT_SERVER  OPENSTACK_NET   172810
# 2017-04-11 08:38:08.408  67601.294  OPENSTACK_NET     EXT_SERVER   170412
# 2017-04-11 08:38:08.599  67601.103     EXT_SERVER  OPENSTACK_NET   148533
# 2017-04-11 08:38:08.599  67601.103  OPENSTACK_NET     EXT_SERVER   147538
#
#                             Bytes       class  Attacker  Normal  Unknown  \
# Date
# 2017-04-05 00:00:09.191        46  suspicious         0       0        0
# 2017-04-05 00:00:09.191        40  suspicious         0       0        0
# 2017-04-05 00:02:56.395        46  suspicious         0       0        0
